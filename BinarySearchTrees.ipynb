# %% [markdown]
# <a href="https://colab.research.google.com/github/Praveen76/Leetcode-DSA/blob/main/BinarySearchTrees.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Example 1: 938. Range Sum of BST
#
# Given the root node of a binary search tree and two integers low and high, return the sum of values of all nodes with a value in the inclusive range [low, high].

# %%
import pandas as pd
from typing import Optional

class TreeNode:
  def __init__(self, val=0, left=None, right=None):
    self.val = val
    self.left = left
    self.right = right

root = TreeNode(0)
left = TreeNode(1)
right = TreeNode(2)
root.left = left
root.right = right

print(root.left.val)
print(root.right.val)
# Out:
# 1
# 2

# %%
class Solution:
  def rangeSumBST(self, root: Optional[TreeNode], low, high):

    # Base case: Empty node
    if not root: return 0
    ans = 0

    if low <= root.val <= high: ans+= root.val
    if root.val > low:
      ans += self.rangeSumBST(root.left, low, high)

    if root.val< high:
      ans += self.rangeSumBST(root.right, low, high)

    return ans

# %% [markdown]
# # Example 2: 530. Minimum Absolute Difference in BST
#
# Given the root of a BST, return the minimum absolute difference between the values of any two different nodes in the tree.

# %%
class Solution:
  def minAbsDiff(self, root: Optional[TreeNode]):
    def dfs(node):
      if not node: return 0

      dfs(node.left)
      values.append(node)
      dfs(node.right)


    # DFS traversal
    values = []
    dfs(root)
    ans = float("-inf")
    for i in range(1, len(values)):
      ans += min(ans, values[i]-values[i-1])

    return ans

# %% [markdown]
# # Example 3: 98. Validate Binary Search Tree
#
# Given the root of a binary tree, determine if it is a valid BST.
